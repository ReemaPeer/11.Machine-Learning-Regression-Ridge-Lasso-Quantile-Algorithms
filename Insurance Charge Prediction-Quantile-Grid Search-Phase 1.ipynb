# %%
# Importing the library and reading the dataset

import pandas as pd
dataset= pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Preprocessing the dataset to convert nominal data to numeric data

dataset = pd.get_dummies(dataset, drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# Getting the column names of the dataset

dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# Splitting the input and the output data

independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes' ]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# Splitting the train and the test data

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(independent, dependent, test_size = 0.30, random_state = 0)

# %%
# Creating Quantile model with grid search

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import QuantileRegressor
grid_params = {'solver':['highs-ds', 'highs-ipm', 'highs', 'interior-point', 'revised simplex'], 'quantile':[0.3,0.5,0.7]}
grid = GridSearchCV(QuantileRegressor(), grid_params, refit = True, verbose = 3, n_jobs = -1)
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# C:\Users\reema\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\reema\anaconda3\Lib\site-packages\sklearn\linear_model\_quantile.py:297: ConvergenceWarning: Linear programming for QuantileRegressor did not succeed.
# Status is 4: Numerical difficulties encountered.
# Result message of linprog:
# The solution does not satisfy the constraints within the required tolerance of 3.16E-04, yet no errors were raised and there is no certificate of infeasibility or unboundedness. Check whether the slack and constraint residuals are acceptable; if not, consider enabling presolve, adjusting the tolerance option(s), and/or using a different method. Please consider submitting a bug report.
#   warnings.warn(
# GridSearchCV(estimator=QuantileRegressor(), n_jobs=-1,
#              param_grid={'quantile': [0.3, 0.5, 0.7],
#                          'solver': ['highs-ds', 'highs-ipm', 'highs',
#                                     'interior-point', 'revised simplex']},
#              verbose=3)

# %%
# Printing the best parameter

re = grid.cv_results_
print("The best Parameters are : {} ".format(grid.best_params_))
# Out:
# The best Parameters are : {'quantile': 0.7, 'solver': 'interior-point'}

# %%
# Printing the parameter in  the table format

table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.165549      0.099240         0.012850        0.010169
# 1        0.076409      0.024661         0.008359        0.004900
# 2        0.062965      0.013388         0.003680        0.003194
# 3       51.080019      5.278035         0.066418        0.077801
# 4       11.481961      0.962748         0.010978        0.007749
# 5        0.130602      0.043777         0.011151        0.013561
# 6        0.101373      0.012151         0.009069        0.006613
# 7        0.093505      0.039725         0.006721        0.008886
# 8       54.914325      1.179803         0.026265        0.024489
# 9       13.591969      0.430785         0.006626        0.001345
# 10       0.141464      0.034468         0.014010        0.013440
# 11       0.117150      0.018697         0.019073        0.016689
# 12       0.130920      0.024448         0.019076        0.010147
# 13      44.895441      2.737773         0.009493        0.010074
# 14      14.786550      1.662717         0.008081        0.005230
#
#    param_quantile     param_solver  \
# 0             0.3         highs-ds
# 1             0.3        highs-ipm
# 2             0.3            highs
# 3             0.3   interior-point
# 4             0.3  revised simplex
# 5             0.5         highs-ds
# 6             0.5        highs-ipm
# 7             0.5            highs
# 8             0.5   interior-point
# 9             0.5  revised simplex
# 10            0.7         highs-ds
# 11            0.7        highs-ipm
# 12            0.7            highs
# 13            0.7   interior-point
# 14            0.7  revised simplex
#
#                                             params  split0_test_score  \
# 0          {'quantile': 0.3, 'solver': 'highs-ds'}          -0.246252
# 1         {'quantile': 0.3, 'solver': 'highs-ipm'}          -0.246252
# 2             {'quantile': 0.3, 'solver': 'highs'}          -0.246252
# 3    {'quantile': 0.3, 'solver': 'interior-point'}          -0.246236
# 4   {'quantile': 0.3, 'solver': 'revised simplex'}          -0.246252
# 5          {'quantile': 0.5, 'solver': 'highs-ds'}          -0.192718
# 6         {'quantile': 0.5, 'solver': 'highs-ipm'}          -0.192718
# 7             {'quantile': 0.5, 'solver': 'highs'}          -0.192718
# 8    {'quantile': 0.5, 'solver': 'interior-point'}          -0.192719
# 9   {'quantile': 0.5, 'solver': 'revised simplex'}          -0.192718
# 10         {'quantile': 0.7, 'solver': 'highs-ds'}          -0.038746
# 11        {'quantile': 0.7, 'solver': 'highs-ipm'}          -0.038746
# 12            {'quantile': 0.7, 'solver': 'highs'}          -0.038746
# 13   {'quantile': 0.7, 'solver': 'interior-point'}          -0.038742
# 14  {'quantile': 0.7, 'solver': 'revised simplex'}          -0.038746
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.036785          -0.294941          -0.321663
# 1           -0.037301          -0.294941          -0.321663
# 2           -0.036785          -0.294941          -0.321663
# 3           -0.037223          -0.294941          -0.321632
# 4           -0.037301          -0.294941          -0.321663
# 5            0.011845          -0.247548          -0.263610
# 6            0.011845          -0.247548          -0.263610
# 7            0.011845          -0.247548          -0.263610
# 8            0.011854          -0.247550          -0.263603
# 9            0.011845          -0.247548          -0.263610
# 10          -0.031691          -0.000333          -0.000157
# 11          -0.031691          -0.000333          -0.000157
# 12          -0.031691          -0.000333          -0.000157
# 13          -0.031684          -0.000334          -0.000157
# 14          -0.031691          -0.000333          -0.000157
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.218809        -0.223690        0.100142               11
# 1           -0.218809        -0.223793        0.099949               15
# 2           -0.218809        -0.223690        0.100142               11
# 3           -0.218799        -0.223766        0.099972               13
# 4           -0.218809        -0.223793        0.099949               14
# 5           -0.165805        -0.171567        0.098352                8
# 6           -0.165805        -0.171567        0.098352                8
# 7           -0.165805        -0.171567        0.098352                8
# 8           -0.165806        -0.171565        0.098354                6
# 9           -0.165805        -0.171567        0.098352                7
# 10          -0.007028        -0.015591        0.016369                3
# 11          -0.007028        -0.015591        0.016369                3
# 12          -0.007028        -0.015591        0.016369                3
# 13          -0.007028        -0.015589        0.016366                1
# 14          -0.007028        -0.015591        0.016369                2

# %%
# Getting the input values for prediction

age_input = float(input('Age: '))
bmi_input = float(input('BMI: '))
children_input = float(input('Children: '))
sex_male_input = float(input('Sex Male 0 or 1: '))
smoker_yes_input = float(input('Smoker yes 0 or 1: '))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
# Predicting the output

Future_predict = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future prediction  = {} ".format(Future_predict))
# Out:
# Future prediction  = [13831.11475208]
# C:\Users\reema\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but QuantileRegressor was fitted with feature names
#   warnings.warn(
